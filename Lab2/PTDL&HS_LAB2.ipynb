# %% [markdown]
# #LAB 2: BÀI THỰC HÀNH TRÌNH BÀY DỮ LIỆU

# %%
import pandas as pd
import numpy as np
df = pd.read_csv("processed_dulieuxettuyendaihoc.csv")
df.head()
# Out:
#    STT   T1   L1   H1   S1   V1   X1   D1   N1   T2  ...  TBM1  TBM2  TBM3  \
# 0    1  7.2  7.3  6.3  7.3  7.0  7.9  7.3  5.5  8.4  ...  7.00  7.54  7.01
# 1    2  5.4  3.9  3.9  4.0  5.4  5.4  5.3  2.8  6.3  ...  4.69  5.47  5.07
# 2    3  5.6  6.8  7.2  7.5  4.3  7.4  5.8  3.2  5.0  ...  5.77  5.38  6.04
# 3    4  6.6  6.4  5.3  6.9  5.4  7.3  6.4  5.8  5.1  ...  6.21  5.20  6.88
# 4    5  6.0  5.0  6.0  7.3  6.5  7.7  7.9  6.1  5.4  ...  6.50  6.36  6.99
#
#    XL1  XL2  XL3  US_TBM1  US_TBM2  US_TBM3  KQXT
# 0    K    K    K    2.800    3.016    2.804   0.0
# 1    Y   TB   TB    1.876    2.188    2.028   0.0
# 2   TB   TB   TB    2.308    2.152    2.416   1.0
# 3   TB   TB    K    2.484    2.080    2.752   0.0
# 4    K   TB    K    2.600    2.544    2.796   0.0
#
# [5 rows x 66 columns]

# %%
def Q1(x):
    return x.quantile(0.25)

def Q2(x):
    return x.quantile(0.50)

def Q3(x):
    return x.quantile(0.75)

# %% [markdown]
# # Phần 1: Thống kê dữ liệu

# %% [markdown]
# 1. Hãy sắp xếp dữ liệu điểm DH1 theo thứ tự tăng dần

# %%
df_DH1_sorted = df.sort_values(by='DH1', ascending=True)
df_DH1_sorted
# Out:
#     STT   T1   L1   H1   S1   V1   X1   D1   N1   T2  ...  TBM1  TBM2  TBM3  \
# 53   54  4.9  5.9  6.2  5.6  5.9  5.0  7.0  5.6  6.1  ...  5.69  6.26  6.02
# 43   44  6.6  7.2  5.9  6.9  7.6  8.1  7.3  6.7  6.3  ...  7.05  6.61  6.77
# 5     6  9.3  7.6  7.9  8.6  7.0  7.3  7.7  7.9  9.6  ...  7.96  8.54  7.38
# 72   73  5.5  6.6  7.2  7.6  5.5  6.7  6.7  5.2  6.0  ...  6.20  5.88  6.22
# 83   84  5.9  5.7  7.1  6.7  6.5  8.0  8.1  4.3  7.4  ...  6.47  7.11  7.47
# ..  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...   ...   ...   ...
# 6     7  2.8  3.9  5.5  6.9  5.0  7.3  4.6  5.2  4.4  ...  4.90  5.60  6.01
# 11   12  7.9  7.0  9.1  8.6  6.1  7.0  5.6  9.0  8.2  ...  7.43  7.72  7.49
# 23   24  5.3  6.3  5.7  6.9  5.9  7.5  6.6  5.1  6.4  ...  6.05  6.32  6.71
# 24   25  2.4  4.1  3.6  5.5  5.9  5.6  4.9  4.2  3.3  ...  4.45  4.88  5.41
# 97   98  8.8  5.5  7.4  7.7  6.2  7.3  8.1  4.5  9.5  ...  7.05  7.84  7.67
#
#     XL1  XL2  XL3  US_TBM1  US_TBM2  US_TBM3  KQXT
# ...

# %% [markdown]
# 2. Hãy sắp xếp dữ liệu điểm DH2 tăng dần theo nhóm giới tính

# %%
df_DH2_sorted_gender = df.sort_values(by=['GT', 'DH2'], ascending=[True, True])
df_DH2_sorted_gender
# Out:
#     STT   T1   L1   H1   S1   V1   X1   D1   N1   T2  ...  TBM1  TBM2  TBM3  \
# 95   96  8.6  6.9  7.4  8.8  7.6  5.8  7.3  5.7  8.9  ...  7.43  7.42  6.83
# 25   26  3.6  5.8  6.9  6.1  5.5  7.2  5.5  4.3  4.2  ...  5.40  5.20  5.09
# 24   25  2.4  4.1  3.6  5.5  5.9  5.6  4.9  4.2  3.3  ...  4.45  4.88  5.41
# 46   47  6.7  6.8  6.4  5.9  5.6  6.4  8.0  6.8  6.6  ...  6.49  6.51  6.16
# 13   14  4.9  5.4  5.0  5.0  5.8  7.0  4.2  5.8  4.5  ...  5.38  5.51  6.26
# ..  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...   ...   ...   ...
# 68   69  7.3  6.4  6.9  7.5  6.2  8.4  7.6  8.1  8.1  ...  7.19  7.70  8.00
# 11   12  7.9  7.0  9.1  8.6  6.1  7.0  5.6  9.0  8.2  ...  7.43  7.72  7.49
# 47   48  7.9  7.6  8.4  8.6  6.2  7.5  8.7  7.7  7.3  ...  7.67  7.49  7.11
# 2     3  5.6  6.8  7.2  7.5  4.3  7.4  5.8  3.2  5.0  ...  5.77  5.38  6.04
# 97   98  8.8  5.5  7.4  7.7  6.2  7.3  8.1  4.5  9.5  ...  7.05  7.84  7.67
#
#     XL1  XL2  XL3  US_TBM1  US_TBM2  US_TBM3  KQXT
# ...

# %% [markdown]
# 3. Hãy tạo pivot-table để thống kê các giá trị count sum, mean, median, min, max, std, Q1, Q2 và Q3 của DH1 theo KT

# %%
pivot_KT = pd.pivot_table(
    df,
    values='DH1',
    index='KT',
    aggfunc=['count', 'sum', 'mean', 'median', 'min', 'max', 'std', Q1, Q2, Q3]
)
pivot_KT
# Out:
#    count     sum      mean median   min   max       std      Q1    Q2     Q3
#      DH1     DH1       DH1    DH1   DH1   DH1       DH1     DH1   DH1    DH1
# KT
# A     49  163.50  3.336735   3.25  1.00  6.50  1.274296  2.2500  3.25  4.250
# A1     6   17.50  2.916667   3.00  2.00  4.25  0.861201  2.1875  3.00  3.250
# B      9   29.50  3.277778   3.50  1.75  4.50  0.823905  3.2500  3.50  3.750
# C     14   79.25  5.660714   5.25  4.75  7.00  0.812209  5.0625  5.25  6.375
# D1    22   84.25  3.829545   3.75  1.25  6.75  1.370146  3.0000  3.75  4.875

# %% [markdown]
# 4. Hãy tạo pivot-table để thống kê các giá trị count, sum, mean, median, min, max, std, Q1, Q2 và Q3 của DH1 theo KT và KV

# %%
pivot_KT_KV = pd.pivot_table(
    df,
    values='DH1',
    index=['KT', 'KV'],
    aggfunc=['count', 'sum', 'mean', 'median', 'min', 'max', 'std', Q1, Q2, Q3]
)
pivot_KT_KV
# Out:
#        count    sum      mean median   min   max       std      Q1     Q2  \
#          DH1    DH1       DH1    DH1   DH1   DH1       DH1     DH1    DH1
# KT KV
# A  1      29  93.75  3.232759  3.250  1.00  6.50  1.369194  2.0000  3.250
#    2       9  31.75  3.527778  3.500  2.00  6.25  1.427653  2.2500  3.500
#    2NT    11  38.00  3.454545  3.500  2.00  4.75  0.913908  2.8750  3.500
# A1 1       2   4.75  2.375000  2.375  2.00  2.75  0.530330  2.1875  2.375
#    2NT     4  12.75  3.187500  3.250  2.00  4.25  0.921389  2.9375  3.250
# B  1       8  25.75  3.218750  3.375  1.75  4.50  0.860207  3.0000  3.375
#    2NT     1   3.75  3.750000  3.750  3.75  3.75       NaN  3.7500  3.750
# C  1       8  43.50  5.437500  5.250  4.75  7.00  0.728869  5.0000  5.250
#    2       2  11.50  5.750000  5.750  5.00  6.50  1.060660  5.3750  5.750
#    2NT     4  24.25  6.062500  6.000  5.25  7.00  0.943729  5.2500  6.000
# D1 1      13  46.75  3.596154  3.500  1.50  5.75  1.264658  2.7500  3.500
# ...

# %% [markdown]
# 5. Hãy tạo pivot-table để thống kê các giá trị count, sum, mean, median, min, max, std, Q1, Q2 và Q3 của DH1 theo KT, KV và DT

# %%
pivot_KT_KV_DT = pd.pivot_table(
    df,
    values='DH1',
    index=['KT', 'KV', 'DT'],
    aggfunc=['count', 'sum', 'mean', 'median', 'min', 'max', 'std', Q1, Q2, Q3]
)
pivot_KT_KV_DT
# Out:
#            count    sum      mean median   min   max       std      Q1     Q2  \
#              DH1    DH1       DH1    DH1   DH1   DH1       DH1     DH1    DH1
# KT KV  DT
# A  1   0.0    29  93.75  3.232759  3.250  1.00  6.50  1.369194  2.0000  3.250
#    2   0.0     8  27.50  3.437500  3.000  2.00  6.25  1.498511  2.2500  3.000
#        6.0     1   4.25  4.250000  4.250  4.25  4.25       NaN  4.2500  4.250
#    2NT 0.0    11  38.00  3.454545  3.500  2.00  4.75  0.913908  2.8750  3.500
# A1 1   0.0     2   4.75  2.375000  2.375  2.00  2.75  0.530330  2.1875  2.375
#    2NT 0.0     4  12.75  3.187500  3.250  2.00  4.25  0.921389  2.9375  3.250
# B  1   0.0     8  25.75  3.218750  3.375  1.75  4.50  0.860207  3.0000  3.375
#    2NT 0.0     1   3.75  3.750000  3.750  3.75  3.75       NaN  3.7500  3.750
# C  1   0.0     8  43.50  5.437500  5.250  4.75  7.00  0.728869  5.0000  5.250
#    2   0.0     2  11.50  5.750000  5.750  5.00  6.50  1.060660  5.3750  5.750
# ...

# %% [markdown]
# Phần 2: Trình bày dữ liệu

# %% [markdown]
# 1. Hãy trình bày dữ liệu biến: GT

# %%
gt = df.groupby('GT')['GT'].agg('count')

# %%
gt.plot.bar()
# Out:
# <Axes: xlabel='GT'>

# %%
gt.plot.pie()
# Out:
# <Axes: ylabel='GT'>

# %%
 gt.plot.area()
# Out:
# <Axes: xlabel='GT'>

# %% [markdown]
# 2. Hãy trình bày dữ liệu lần lượt các biến: US_TBM1, US_TBM2 và US_TBM3

# %%
cau22 = pd.DataFrame(df, columns = ['US_TBM1', 'US_TBM2', 'US_TBM3'])

# %%
cau22.describe()
# Out:
#           US_TBM1     US_TBM2    US_TBM3
# count  100.000000  100.000000  100.00000
# mean     2.434480    2.559600    2.67176
# std      0.391203    0.377656    0.29981
# min      1.616000    1.768000    1.91600
# 25%      2.107000    2.223000    2.47300
# 50%      2.480000    2.588000    2.70600
# 75%      2.724000    2.893000    2.87400
# max      3.232000    3.416000    3.31600

# %% [markdown]
# 3. Hãy trình bày dữ liệu biến DT với các học sinh là nam

# %%
cau23 = df[df["GT"] == "M"]
nam_dt_counts = cau23['DT'].value_counts()

# %%
nam_dt_counts.plot.bar()
# Out:
# <Axes: xlabel='DT'>

# %% [markdown]
# 4. Hãy trình bày dữ liệu biến KV với các học sinh là nam thuộc dân tộc Kinh, có điểm thỏa mãn điều kiện (DH1 >= 5.0 và DH2 >= 4.0 và DH3 >= 4.0)

# %%
cau24 = df[(df['GT'] == 'M') &
                 (df['DT'] == 0.0) &
                 (df['DH1'] >= 5.0) &
                 (df['DH2'] >= 4.0) &
                 (df['DH3'] >= 4.0)]
kv_counts = cau24['KV'].value_counts()

# %%
kv_counts.plot.bar()
# Out:
# <Axes: xlabel='KV'>

# %% [markdown]
# 5. Hãy trình bày dữ liệu lần lượt các biến DH1, DH2, DH3 lớn hơn bằng 5.0 và thuộc khu
# vực 2NT

# %%
cau25 = df[(df["KV"] == "2NT") &
    (df["DH1"] >= 5.0) &
    (df["DH2"] >= 5.0) &
    (df["DH3"] >= 5.0)
][["DH1", "DH2", "DH3"]]

cau25.describe()
# Out:
#         DH1   DH2  DH3
# count  1.00  1.00  1.0
# mean   6.75  5.25  5.0
# std     NaN   NaN  NaN
# min    6.75  5.25  5.0
# 25%    6.75  5.25  5.0
# 50%    6.75  5.25  5.0
# 75%    6.75  5.25  5.0
# max    6.75  5.25  5.0

# %%
cau25.plot(kind="box")
# Out:
# <Axes: >

# %% [markdown]
# Phần 3: Trực quan hóa dữ liệu theo nhóm phân loại

# %% [markdown]
# 1. Trực quan dữ liệu học sinh nữ trên các nhóm XL1, XL2, XL3 dạng unstacked
#
# Gợi ý
# - Lọc dữ liệu giới tính là nữ
# - Oy: Chiều cao biểu đồ cột thể hiển số lượng học sinh theo xếp loại
# - Màu sắc thể hiện giá trị xếp loại: [Y, TB, K, G, XS]
# - Ox: thể hiện nhóm XL1, XL2 và XL3

# %%
cau31 = df[df["GT"] == "F"]
xl1 = cau31["XL1"].value_counts()
xl2 = cau31["XL2"].value_counts()
xl3 = cau31["XL3"].value_counts()

xl_df = pd.DataFrame({"XL1": xl1,"XL2": xl2,"XL3": xl3}).fillna(0)

# %%
xl_df.plot.bar()
# Out:
# <Axes: >

# %% [markdown]
# 2. Trực quan dữ liệu KQXT trên nhóm học sinh có khối thi A, A1, B thuộc khu vực 1, 2

# %%
cau32 = df[(df["KT"].isin(["A", "A1", "B"])) &
            (df["KV"].isin(['1', '2']))]
kqxt_count = pd.crosstab(cau32["KT"], cau32["KQXT"])
kqxt_count
kqxt_count.plot.bar()
# Out:
# <Axes: xlabel='KT'>

# %% [markdown]
# 3. Trực quan dữ liệu số lượng thí sinh từng khu vực dựa trên từng nhóm khối thi

# %%
cau33 = pd.crosstab(df["KT"], df["KV"])
cau33.plot.bar()
# Out:
# <Axes: xlabel='KT'>

# %% [markdown]
# 4. Trực quan dữ liệu số lượng thí sinh đậu, rớt trên từng nhóm khối thi

# %%
cau34 = df[df["KQXT"].notna()].copy()
cau34["KQXT"] = cau34["KQXT"].astype(int)
kqxt_khoi = pd.crosstab(cau34["KT"], cau34["KQXT"])
kqxt_khoi.plot.bar()
# Out:
# <Axes: xlabel='KT'>

# %% [markdown]
# 5. Trực quan dữ liệu số lượng thí sinh đậu rớt trên từng nhóm khu vực.

# %%
cau35 = df[df["KQXT"].notna()].copy()
cau35["KQXT"] = cau35["KQXT"].astype(int)
kqxt_khoi = pd.crosstab(cau35["KV"], cau35["KQXT"])
kqxt_khoi.plot.bar()
# Out:
# <Axes: xlabel='KV'>

# %% [markdown]
# 6. Trực quan dữ liệu số lượng thí sinh đậu rớt dựa trên từng nhóm dân tộc

# %%
cau36 = df[df["KQXT"].notna()].copy()
cau36["KQXT"] = cau36["KQXT"].astype(int)
kqxt_khoi = pd.crosstab(cau36["DT"], cau36["KQXT"])
kqxt_khoi.plot.bar()
# Out:
# <Axes: xlabel='DT'>

# %% [markdown]
# 7. Trực quan dữ liệu số lượng thí sinh đậu rớt dựa trên từng nhóm giới tính.

# %%
cau37 = df[df["KQXT"].notna()].copy()
cau37["KQXT"] = cau37["KQXT"].astype(int)
kqxt_khoi = pd.crosstab(cau37["GT"], cau37["KQXT"])
kqxt_khoi.plot.bar()
# Out:
# <Axes: xlabel='GT'>

# %% [markdown]
# #Phần 4: Trực quan hóa dữ liệu nâng cao

# %% [markdown]
# 1. Vẽ biểu đồ đường Simple cho biến T1

# %%
import matplotlib.pyplot as plt
plt.plot(df["T1"])
plt.xlabel("T1")
plt.ylabel("Count")
# Out:
# Text(0, 0.5, 'Count')

# %% [markdown]
# 2. Hãy tạo biến phân loại (phanlopt1) cho môn toán (T1) như sau:
#
# a. Từ 0 đến dưới 5 = kém (ký hiệu “k”)
#
# b. Từ 5 đến dưới 7 = trung bình (ký hiệu “tb”)
#
# c. Từ 7 đến dưới 8 = khá (ký hiệu “k”)
#
# d. Từ 8 trở lên = giỏi (ký hiệu “g”)

# %%
def phanloai_t1(x):
    if x < 5:
        return "k"
    elif x < 7:
        return "tb"
    elif x < 8:
        return "kh"
    else:
        return "g"
df["phanlopt1"] = df["T1"].apply(phanloai_t1)
df[["T1", "phanlopt1"]].head()
# Out:
#     T1 phanlopt1
# 0  7.2        kh
# 1  5.4        tb
# 2  5.6        tb
# 3  6.6        tb
# 4  6.0        tb

# %% [markdown]
# 3. Lập bảng tần số cho biến phanloait1

# %%
tan_so_phanlopt1 = df["phanlopt1"].value_counts()
tan_so_phanlopt1
# Out:
# phanlopt1
# tb    46
# k     23
# kh    19
# g     12
# Name: count, dtype: int64

# %% [markdown]
# 4. Vẽ biểu đồ đường Multiple Line cho biến T1 được phân loại bởi biến phanlopt1

# %%
df[["T1", "phanlopt1"]].head()
for loai in df["phanlopt1"].unique():
    subset = df[df["phanlopt1"] == loai]
    plt.plot(subset.index, subset["T1"], label=loai)
plt.xlabel("T1")
plt.ylabel("Count")
# Out:
# Text(0, 0.5, 'Count')

# %%
multi_line_data = (
    df.groupby(["T1", "phanlopt1"])
      .size()
      .reset_index(name="Count")
)
for nhom in multi_line_data["phanlopt1"].unique():
    data_nhom = multi_line_data[multi_line_data["phanlopt1"] == nhom]
    plt.plot(
        data_nhom["T1"],
        data_nhom["Count"],
        label=nhom
    )
plt.xlabel("T1")
plt.ylabel("Count")
plt.legend(title="Phanlopt1")

# %% [markdown]
# 5. Vẽ biểu đồ Drop-line cho biến T1 được phân loại bởi biến phanlopt1

# %%
drop_data = df.groupby(["T1", "phanlopt1"]).size().reset_index(name="Count")
for nhom in drop_data["phanlopt1"].unique():
    data_nhom = drop_data[drop_data["phanlopt1"] == nhom]

    plt.vlines(
        x=data_nhom["T1"],
        ymin=0,
        ymax=data_nhom["Count"],#
        linewidth=2
    )
    plt.scatter(
        data_nhom["T1"],
        data_nhom["Count"],
        label=nhom
    )

plt.xlabel("T1")
plt.ylabel("Count")
plt.legend(title="Phanlopt1")

# %% [markdown]
# # Phần 5: Mô tả dữ liệu và khảo sát dạng phân phối

# %% [markdown]
# 1. Hãy mô tả và khảo sát phân phối cho biến T1

# %%
import seaborn as sns
import scipy.stats as stats

# %%
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
sns.boxplot(y=df['T1'])
plt.title('Box-plot T1')
plt.subplot(1, 2, 2)
df['T1'].hist(edgecolor='black')
plt.title('Histogram T1')
plt.show()

plt.figure()
stats.probplot(df['T1'], dist="norm", plot=plt)
plt.title('QQ-Plot T1')
plt.show()

# %% [markdown]
# 2. Hãy mô tả và khảo sát phân phối cho biến T1 trên từng nhóm phân lớp (phanlopT1)

# %%
g = sns.FacetGrid(df, col="phanlopt1")
g.map(plt.hist, "T1", edgecolor='black')
plt.show()

# %% [markdown]
# 3. Hãy khảo sát tương quan giữa biến DH1 theo biến T1

# %%
sns.scatterplot(x='T1', y='DH1', data=df)
plt.title(f"Scatter plot T1 vs DH1 (Corr: {df['T1'].corr(df['DH1']):.2f})")

plt.show()

# %% [markdown]
# 4. Hãy khảo sát tương quan giữa biến DH1 theo biến T1 trên từng nhóm khu vực

# %%
sns.lmplot(x='T1', y='DH1', hue='KV', data=df)
plt.title('Tương quan DH1 vs T1 theo Khu vực')
plt.show()

# %% [markdown]
# 5.Hãy khảo sát tương quan giữa các biến DH1, DH2,  DH3

# %%
sns.pairplot(df[['DH1', 'DH2', 'DH3']])
plt.show()
